# %% [markdown]
# # Benchmark example with Fibonacci functions

# %% [markdown]
# #### Import the modules

# %%
import numpy as np
from benchmark_utils import plot_efficiencies
from benchmark_functions import fibonacci, fibonacci_memo

# %% [markdown]
# #### Some variables for the benchmark

# %%
RUNS = 10
LOOPS = 100

# %% [markdown]
# #### Some variables for the functions

# %%
LIST_FUNCTIONS = [
    fibonacci,
    fibonacci_memo
]
VARIABLE_NAME = 'n'
VALUES = np.arange(20)

# %%
plot_efficiencies(
    func_list=LIST_FUNCTIONS,
    var_iter=VARIABLE_NAME,
    value_iter=VALUES,
    runs=RUNS,
    loops=LOOPS,
)
